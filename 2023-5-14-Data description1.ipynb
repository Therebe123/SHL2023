# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#training
#Training/Hand
df1_label=pd.read_pickle("/home/ossdata/dengjiebi/data_pkl/train/hand_label_full.pkl")
#Training/Hips
df1_label=pd.read_pickle("/home/ossdata/dengjiebi/data_pkl/train/hand_label_full.pkl")

# %%
#Training/Hand label distribution
result =[]
result = df_hand_label['label'].value_counts(ascending=True) 
label_dic = {1:'Still',2:'Walking',3:'Run',4:'Bike', 5:'Car', 6:'Bus', 7:'Train',8:'Subway'}
plt.pie(result, autopct='%1.1f%%', labels=label_dic)
plt.title('Training/Hand label distribution')
plt.show()

# %%
#Training/Hips label distribution
result =[]
result = df_hips_label['label'].value_counts(ascending=True) 
label_dic = {1:'Still',2:'Walking',3:'Run',4:'Bike', 5:'Car', 6:'Bus', 7:'Train',8:'Subway'}
plt.pie(result, autopct='%1.1f%%', labels=label_dic)
plt.title('Training/Hips label distribution')
plt.show()

# %%
#Training/Torso label distribution
result =[]
result = df_torso_label['label'].value_counts(ascending=True) 
label_dic = {1:'Still',2:'Walking',3:'Run',4:'Bike', 5:'Car', 6:'Bus', 7:'Train',8:'Subway'}
plt.pie(result, autopct='%1.1f%%', labels=label_dic)
plt.title('Training/Torso label distribution')
plt.show()

# %%
#Training/Bag label distribution
result =[]
result = df_bag_label['label'].value_counts(ascending=True) 
label_dic = {1:'Still',2:'Walking',3:'Run',4:'Bike', 5:'Car', 6:'Bus', 7:'Train',8:'Subway'}
plt.pie(result, autopct='%1.1f%%', labels=label_dic)
plt.title('Training/Bag label distribution')
plt.show()

# %% [markdown]
# ## train set

# %%
train=pd.read_pickle("/home/ossdata/dengjiebi/data_pkl/train/bag_label_full.pkl")

# %%
result =[]
result = train['label'].value_counts() 
result
# Out:
# label
# 5    15869847
# 7    15625987
# 6    14164261
# 2    12276890
# 1    12229754
# 8    11917619
# 4    11740364
# 3     4227716
# Name: count, dtype: int64

# %%
label_dic = {1:'Still',2:'Walking',3:'Run',4:'Bike', 5:'Car', 6:'Bus', 7:'Train',8:'Subway'}
labelt=[]
for i in [5,7,6,2,1,8,4,3]: 
    labelt.append(label_dic[i])
    print(label_dic[i])
    
print(labelt)
# Out:
# Car
# Train
# Bus
# Walking
# Still
# Subway
# Bike
# Run
# ['Car', 'Train', 'Bus', 'Walking', 'Still', 'Subway', 'Bike', 'Run']

# %%
colors = ['tomato', 'lightskyblue', 'goldenrod', 'green', 'y','thistle','lavender','palegreen']
palette_color=sns.color_palette("RdYlBu",8)
plt.figure(figsize=(9, 9))
plt.pie(result, autopct='%1.1f%%', labels=labelt, colors=palette_color,textprops={'fontsize': 16, 'color': 'black'})
plt.title('Train Label Distribution',fontsize=19)
plt.show()

# %%
val=pd.read_pickle("/home/ossdata/dengjiebi/data_pkl/validate/bag_label_full.pkl")
resultv =[]
resultv = val['label'].value_counts() 
resultv
# Out:
# label
# 1    2983752
# 2    2614854
# 7    2180992
# 8    2170727
# 5    2047370
# 4    1203050
# 6     917808
# 3     277388
# Name: count, dtype: int64

# %%
label_dic = {1:'Still',2:'Walking',3:'Run',4:'Bike', 5:'Car', 6:'Bus', 7:'Train',8:'Subway'}
labelv=[]
for i in [1,2,7,8,5,4,6,3]: 
    labelv.append(label_dic[i])
    print(label_dic[i])
    
print(labelv)
# Out:
# Still
# Walking
# Train
# Subway
# Car
# Bike
# Bus
# Run
# ['Still', 'Walking', 'Train', 'Subway', 'Car', 'Bike', 'Bus', 'Run']

# %%
colors = ['tomato', 'lightskyblue', 'goldenrod', 'green', 'y','thistle','lavender','palegreen']
palette_color=sns.color_palette("RdYlBu",8)
plt.figure(figsize=(9, 9))
plt.pie(resultv, autopct='%1.1f%%', labels=labelv, colors=palette_color,textprops={'fontsize': 16, 'color': 'black'})
plt.title('Validation Label Distribution',fontsize=19)
plt.show()
